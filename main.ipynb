# %% [markdown]
# # IMPORTS

# %%
from decimal import Decimal

import rdkit
from rdkit import Chem

# %% [markdown]
# # set PATHS

# %%
DATA_PATH = '/home/artem/dataset_gdb17/GDB17.50000000.smi'

# %% [markdown]
# # READ DATA

# %%
supplier = Chem.SmilesMolSupplier(DATA_PATH)

# %% [markdown]
# ## Essential Information about the data

# %%
data_length = len(supplier)
print(f'length of the data set: {Decimal(data_length):.2E}')

# mols = [mol for mol in supplier]
# Out:
# length of the data set: 5.00E+7
# RDKit WARNING: [09:30:24] WARNING: no name column found on line 1
# RDKit WARNING: [09:30:24] WARNING: no name column found on line 2
# RDKit WARNING: [09:30:24] WARNING: no name column found on line 3
# RDKit WARNING: [09:30:24] WARNING: no name column found on line 4
# RDKit WARNING: [09:30:24] WARNING: no name column found on line 5
# RDKit WARNING: [09:30:24] WARNING: no name column found on line 6
# RDKit WARNING: [09:30:24] WARNING: no name column found on line 7
# RDKit WARNING: [09:30:24] WARNING: no name column found on line 8
# RDKit WARNING: [09:30:24] WARNING: no name column found on line 9
# RDKit WARNING: [09:30:24] WARNING: no name column found on line 10
# RDKit WARNING: [09:30:24] WARNING: no name column found on line 11
# RDKit WARNING: [09:30:24] WARNING: no name column found on line 12
# RDKit WARNING: [09:30:24] WARNING: no name column found on line 13
# RDKit WARNING: [09:30:24] WARNING: no name column found on line 14
# ...

# %%
# print(mols[0:10])

# %%
print('hello')
